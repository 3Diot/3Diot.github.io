# %%
as it turns out, there has always been a spherical object you could place and scale from the build menu... this is a giant womp portal 😂
- Cluny

# %%
sry didnt realize same person 😅  Cluny explained it better. yes the Polytext feature is usually for placing 3D text.. words.. but, we forgot to turn collision off when it gets nudged outside of a parcel
- bitpixi

from the parcel add menu add a "polytext" feature as shown . Make the text of the polytext be just a lower case i 
i
  . The font of the polytext is such that a lower case i is just a rectangle. Resize that lower case i (and rotate it) to be the size of your pier - the polytext letter is collideable outside of the parcel boundary. You can hide the letter by sinking it just inside your pier. Let me know if you have questions


Heya, we don't allow collision outside parcels.

People exploit a bug in polytext and hide the polytext down
bitpixi.eth — 01/14/2022
People (on team, and users) debate on the polytext bug/feature all the time. What would you think about a way for suburbs to vote on if they want anything outside bounds or not?

# %%
https://cdn.discordapp.com/attachments/431671342044020749/943049399041417236/unknown.png

# %%
curved photos
solid objects
texture baking
invisible walls
https://www.youtube.com/watch?v=jrK3EINyF3Y&t=2589s

# %% [markdown]
# So if our voxels are 0.5m, and you stand next to voxels, you'll see our default avatar is about 1.75m, making walking in 2m tunnels kind of tricky, but 2.5 being fine

# %% [markdown]
# Use a vidscreen to control vox models!

# %%
feature.on('keys', e => {  
  k = e.keys
  player = parcel.players[0]
  boat = parcel.getFeatureById('boat') 
  x = boat.position.x
  y = boat.position.y
  z = boat.position.z 
  player.position.x = player.position.x + 1 
  //if(k.a){ y = y + 1 }
  //else if(k.b){ y = y - 1 }
  if(k.down){ x = x + 1 }
  else if(k.up){ x = x - 1 }
  else if(k.right){ z = z + 1 }
  else if(k.left){ z = z - 1 }
  boat.set({'position': [x, y, z] }) 
} )

# %% [markdown]
# # Games

# %% [markdown]
# capture the flag
#
# tag
#
# hide and go seek
#
# bumpbox
#
# jump into pool from height
#
# simple slides
#
# Airhock / control Vox models
#
# costume contest
