# %% [markdown]
# # CryptoVoxels Example Report!

# %% [markdown]
# I pulled data from: https://www.k1ic.com/cv-zh.html

# %%
#hide 
import sys
sys.path.append('/workspaces/3Diot.github.io/blog/')
sys.path.append('/workspaces/3Diot.github.io/docs/datasets/')

# %%
#hide 
#cd /workspaces/3Diot.github.io/blog/docs/datasets

# %%
#hide_input 
import pandas as pd
pd.read_csv('cv_stats_20211025.csv').head(5)
# Out:
#    Parcel_Id                           Name  \
# 0          1  @westcoastbill 21x: space age
# 1          2                       Welcome!
# 2          3  @westcoastbill 21x: stone age
# 3          4  @westcoastbill 21x: glass age
# 4          5                       Hackatao
#
#                                          Description  Traffic_Visits  \
# 0  Thank you Nick/Ben.  We won't let you down. le...          150445
# 1  Welcome to Cryptovoxels! This build was done b...          138831
# 2  Thank you Ben/Sam.  We won't let you down. lea...          105459
# 3                     www.twitter.com/westcoastbill           163861
# 4                                                              34946
#
#                                         Owner  \
# 0  0x290fbe4d4745f6b5267c209c92c8d81cebb5e9f0
# 1  0x2d891ed45c4c3eab978513df4b92a35cf131d2e2
# 2  0x290fbe4d4745f6b5267c209c92c8d81cebb5e9f0
# 3  0x290fbe4d4745f6b5267c209c92c8d81cebb5e9f0
# 4  0xe7079eec020ddfc3f1c0abe1d946c55e6ed30eb3
#
#                                         Contributors  Kind  Area  Height  \
# 0  0xDC9B3A05DB94B951A81c8A23bF2CDB16009b716c|0x4...  plot   234       9
# 1  0xb823dc506011eedab6f8feecc88806dbfc55ea93|0x4...  plot   270       8
# 2  0xDC9B3A05DB94B951A81c8A23bF2CDB16009b716c|0x4...  plot   299      13
# 3  0x2d891ed45c4c3eab978513df4b92a35cf131d2e2|0xD...  plot   420      13
# 4         0x21316e6a4f0af45e5f1503984e83b10c53b177d8  plot    99       6
#
#          Address  Distance       Island      Suburb  Price_Bought_At  \
# 0  70 Block Fork         2  Origin City  The Center                0
# 1  72 Block Fork         2  Origin City  The Center                0
# 2  74 Block Fork         2  Origin City  The Center                0
# 3  75 Block Fork         2  Origin City  The Center                0
# 4  76 Block Fork        19  Origin City  The Center                0
#
#    Feature_Total  Depth  Width
# 0            483     18     13
# 1             71     15     18
# 2            230     13     23
# 3            566     20     21
# 4              4     10     10

# %% [markdown]
# - https://www.cryptovoxels.com/grid/parcels/5657/at/2356b1dc9e81ef62dfdd0f2bd269a765d173942e
# includes voxel positions, isgrid, label, coords, etc.
#
# - https://www.cryptovoxels.com/api/parcels/resources/0x7b19b42564ad1c03625e8306cf20deea2f923a67.json
# only features really
#
# - https://mp.crvox.com/api/parcels/5657.json
# users in parcel
#
# - https://www.cryptovoxels.com/api/mails/unread/by/0x7b19b42564ad1c03625e8306cf20deea2f923a67.json
# unread mail
#
# - https://www.cryptovoxels.com/api/avatars/0x7b19b42564ad1c03625e8306cf20deea2f923a67.json
# avatars
#
# - https://www.cryptovoxels.com/api/mails/by/0x7b19b42564ad1c03625e8306cf20deea2f923a67.json?1632886203750
# all mails sent by me
#
#
# - https://nonfungible.com/market/history/cryptovoxels
# - https://www.yuque.com/docs/share/37a69d60-ea8c-4c92-947e-4132bddf2781?#84PT
# - https://free3d.com/3d-models/obj?page=3
# - https://voxelarchitects.com/portfolio
# - http://ephtracy.github.io/index.html?page=mv_resource
# - https://www.megavoxels.com/p/magicavoxel-tutorials.html
# - https://wiki.cryptovoxels.com/Player_customization/Create_a_wearable
# - https://www.cryptovoxels.com/marketplace/collections#
#
#
# - https://www.k1ic.com/cvs-zh.html
# - https://docs.opensea.io/
