# %% [markdown]
# # Inspirational
# > Here's a list of parcels I like!
#
# - toc: true
# - filename: Inspiration
# - tab: CVMinigames | Inspiration
# - title: CVMinigames
# - template: article
# - description: this isnt working
# - image: images/company_logo.png
# - keywords: thisworks
# - badges: true
# - comments: true
# - categories: [test]
# - hide: false
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2

# %% [markdown]
# Below are a list of some of my favorite builders and or builds :D

# %% [markdown]
# This page will constantly evolve but it's still in the early stages.

# %% [markdown]
# - [Welcome to VoxCon!](https://www.cryptovoxels.com/parcels/7368) - Is where we are hosting the event for our rebranding event.
# - [MoCA](https://www.cryptovoxels.com/parcels/364)
# - [B.20 Monument](tps://www.cryptovoxels.com/parcels/1162) - This neighborhood is one of the oldest in cryptovoxels and housed the largest parcels in the world until recently. Be sure to look around since these properties go for top-dollar given location and space!
# - [Vox Walk](https://www.cryptovoxels.com/parcels/4979)
# - [Ogar Art & Architecture](https://www.cryptovoxels.com/parcels/3725) - This is a master builder. The link I sent is a showcase of all his other builds. I'd highly recommend you take a look through em.
# - [Juicebox Lounge](https://www.cryptovoxels.com/parcels/6188)
# - [Architect Island](https://www.cryptovoxels.com/parcels/7596) - This is still being developed but showcase really beautiful building shells we hope to sell for people to fill the interior of.
# - [Octo Bar](https://www.cryptovoxels.com/parcels/2714)
# - [The Dome Catwalk - > https://www.cryptovoxels.com/parcels/3296)
# - [Temple of Doge](https://www.cryptovoxels.com/parcels/4461)
# - [Token Smart Theater](https://www.cryptovoxels.com/parcels/2934)
# - [$Whale Pagoda](https://www.cryptovoxels.com/parcels/2367) - crypto "$Whale" project has commissioned a bunch of fine properties to take a look at.
# - [Brookhawks estate](https://www.cryptovoxels.com/parcels/2476)
# - [Fabio Ema's Holiday Build](https://www.cryptovoxels.com/parcels/163) - Build won third place in a contest. If you look around you'll find quite a few other holiday themed builds around the block you may find interesting.
# - [Marble Tower](https://www.cryptovoxels.com/parcels/1278)
# - The Dome Catwalk -> Often holds fashion shows from NFT creators. You can see some of the clothes on display. Around the block is a crypto zoo with an interesting story.
# - [https://www.cryptovoxels.com/play?coords=E@6647W,115N,5.5U]()
