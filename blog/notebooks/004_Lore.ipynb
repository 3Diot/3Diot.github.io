# %% [markdown]
# Start of the new year, I'll start building out a prototype for our minigame. Users drop embed code 1-per-parcel that loads up the actual game-logic. First, it'd check the content of the parcel for discoveries that may signify that places "role". Secondly, it looks at the hats/discoveries being worn by a user. From there it gets a bit iffy, but from what I see, we'd need some rules governing how players can interact with the space, NPC's in the space, and  with other users; given the spaces 'role' and the users equipped items.  People should be able to contribute and configure their own assets or NPCs to the game with generic properties and support for NPCs to have conditional conversations based on assets worn and the users progress in the mini-games 'story-line'. This would require an external server to handle the management of all these rules, dialogs, and 'state' information of the user.

# %% [markdown]
# # CV Stories and Lore
# > An introductory article to Cryptovoxels' Parcel Data
#
# - toc: true
# - filename: Scarcity
# - tab: CVMinigames | Scarcity
# - title: CVMinigames
# - template: article
# - description: this isnt working
# - image: images/company_logo.png
# - keywords: thisworks
# - badges: true
# - comments: true
# - categories: [test]
# - hide: false
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2

# %%
# %%capture
# !pip install requests

# %% [markdown]
# With the introduction of Scarcity Island, a burgeoning story has began to form in the CV-Metaverse.
#
# Lit by Bitpixi and brought into reality by the CV dev team, 'Scarcity-Discoveries' have ignited a fire in our hearts and minds.
#
# Since their reveal, a dauntless core of of creatives have banded (loosely) together to keep our "cosa nostra" rolling.
#
# Below you will find a breakdown of each of these participants and their contributions towards the ever-developing CV Meta Story.

# %% [markdown]
# ## Bitpixi

# %% [markdown]
# Who better to kick off our list but the one who started it all?

# %% [markdown]
# Bitpixi, who works for Cryptovoxels, introduced us CVlians to the dwarfs of Scarcity Island.
#
# In and amongst the basements of Scarcity Island were strange discoveries to be found. What were they and where did they come from? It appeared at first that only Bitpixi could tell.

# %% [markdown]
# A prolific writter, [Bitpixi's blog](https://medium.com/@kasey_2741) held the keys to explaining what all this was about.

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <img src='https://charleskarpati.com/cv/images/bitpixi_creations-min.JPG' height='450px'>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1487543453861003281"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <img src='https://charleskarpati.com/cv/images/bitpixi_creations-min.JPG' height='450px'>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1487543453861003281"></a>
# </blockquote>

# %% [markdown]
# As days turn to weeks and weeks to months, we can only hope for more of her creative juices to splash upon a new page of writing.
#
# While we wait, here is what we know:

# %% [markdown]
# Unknown whether it’s by Celxi Pebblestone as well, a fan of her work, or a forger
# but they use her color palettes
# She’s a middle class modern artist gnome who kind of predates / ignores cyberpunk faction? Her famous series are based on the 7 days of the gnomish week, and so too are the statues
# So to figure out if she’s also the artist of the statues, maybe examine if anyone used any special machines, or just regular materials in the process? That might be a clue

# %% [markdown]
# Just wait until you see my Rare Coprolith of a Roginspar Aqrabuamelu Face with tears of joy (the fossilized poop of a half-scorpion half-man who can animate statues and render zombie parasites harmless with a cold fire.. who was once a statue himself by gnome artist Thistle Rogin) Gnome recursion...
#
# But there will also be small dragon and giant tortoise poop fossils. Bet

# %%
import json
import urllib.request as request

# Scarcity Discoveries

t = []
for i in range(0,200):
  url = f"https://www.cryptovoxels.com/c/698/{i}"; print (url)
  try:
    response = request.urlopen(url)
    data_json = json.loads(response.read()) 
    for attr in data_json['attributes']: data_json[ attr['trait_type'] ] = attr['value']
    del data_json['attributes']  
    t.append(data_json)
  except: pass

# %%
import pandas as pd
df = pd.DataFrame(t)

# %%
def fn(name,description, arr): return 1 if ( ( any(ext in description for ext in arr) ) or ( any(ext in name for ext in arr) ) ) else 0 
cdf = df.drop(columns=['suppressed', 'background_color', 'author'] )
cdf['f'] = cdf.apply(lambda x: fn(x['name'].lower(),x['description'].lower(), ['fire ', 'lava'],),axis=1)
cdf['w'] = cdf.apply(lambda x: fn(x['name'].lower(),x['description'].lower(), ['water ', 'ocean']),axis=1)
cdf['e'] = cdf.apply(lambda x: fn(x['name'].lower(),x['description'].lower(), ['earth ']),axis=1)
cdf['a'] = cdf.apply(lambda x: fn(x['name'].lower(),x['description'].lower(), ['air ']),axis=1)
cdf['c'] = cdf.apply(lambda x: fn(x['name'].lower(),x['description'].lower(), [' cyber']),axis=1)
cdf['d'] = cdf.apply(lambda x: fn(x['name'].lower(),x['description'].lower(), ['dark ']),axis=1)
cdf['s']= cdf.iloc[:, -6:].sum(axis=1)
cdf['s'] = cdf.apply(lambda x: 0 if x['s'] else 1,axis=1)
cdf.rename(columns={'external_url': 'id', 'image':'img', 'description':'desc'}, inplace=True)
cdf['id'] = cdf['id'].str.split('/').str[-1]
cdf['img'] = cdf['img'].str.split('/').str[-1]
cdf['vox'] = cdf['vox'].str.split('/').str[-2]
data = cdf.to_json('./scarcity-discoveries.json', orient='records')

# %%
cdf.head()
# Out:
#                              name  ...  s
# 0  Scarcity Mining Club - Pickaxe  ...  1
# 1            The Lost Gnomes Lamp  ...  1
# 2            Scarcity Coin - Gold  ...  1
# 3          Scarcity Coin - Silver  ...  1
# 4          Scarcity Coin - Bronze  ...  1
#
# [5 rows x 14 columns]

# %%
cdf.to_csv('scarcity.csv')

# %% [markdown]
# ## The_Philosopher

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488507532536598528"></a>
# </blockquote>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488467075756662788"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488507532536598528"></a>
# </blockquote>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488467075756662788"></a>
# </blockquote>

# %%
import json
import urllib.request as request

# The Philosopher Brand
# https://cryptovoxelscyberpunks.blogspot.com/

t = []
for i in [574, 573, 572, 571, 570, 569, 568, 567, 566, 565, 564, 554, 553, 552, 551, 550, 549, 548, 547, 546, 546, 544, 536, 534, 532, 530, 528, 527, 527, 509, 508, 507, 506]:
  url = f"https://www.cryptovoxels.com/c/294/{i}"; print (url)
  try:
    response = request.urlopen(url)
    data_json = json.loads(response.read()) 
    for attr in data_json['attributes']: data_json[ attr['trait_type'] ] = attr['value']
    del data_json['attributes']  
    t.append(data_json)
  except: pass

# %%
This is the story up to now. 

A long time ago, when Scarcity was called Abundance, there were no factions, and all gnomes lived a life of happiness and abundance. Abundance grew in technology and wealth, and the gnomes developed wonderful machines with god-like capabilities, 
like teleport, time machines and they could even talk to the dead. 

But Necro, a gnome interested in the old dark arts, was not satisfied with talking to the dead. Her wife was killed in a lab accident, and he wanted to resurrect her. This was not an easy task, and for doing so Necro gathered a large group of gnomes to go to 
Flora meet the great immortal druid. Klava, the druid was alive since immemorial ages, and he is known for being immortal and for having an open passage to the underworld. 

While the decades passed and the new dark gnomes learnt about life and death with Klava, some gnomes from Abundance decide to start mining their fellow lands. These gnomes liked the work on the mines, and Drog convince them all in a town meeting that they 
should mine the empty land from the gnomes that followed Necro. Although many people disagreed, there was a large group of gnomes following Drog, and the other ones, as they were not affected, decided not to act against Drog and the new Earth Faction.

The mayor, Tilt, only cared about the expansion of the Abundance Empire, and he was not in the island when Drog called the town meeting. Tilt was looking for Atlantis with the island army deep inside the ocean. The old legends told that Atlantis people had a 
marvelous treasure full of magic items; and gnomes love to transform magic in technology. The Water Faction was formed by Tilt’s followers that were looking for magic in the depths of the ocean, but they were not a faction until they returned and saw 
Abundance turned into Scarcity.

The Air Faction was formed a long time ago, and maybe it was the 2nd specialized profession from the gnomes’ island. They were the air vehicle builders. Thanks to the Air Gnomes, society developed so much, and it was possible to build so much wealth. 
Thanks to their powerful machines, the gnomes could explore the vastity of the metaverse and they could mine every Cryptovoxels island before they are minted. The air vehicle builders were responsible for 1st  expansion of the Abundance Empire and they 
were the first rulers of the new empty conquered islands. So, when Drog’s voting took place, they were not there to speak their mind, and they did not see what was going on until the many factions were together again, one more time, in the new Scarcity.

All the weapons and mining instruments of Abundance island were made by wonderful blacksmiths, specialized in metal work. As the island got empty, becase Necro, Tilt, the air faction and their followers left the island, the blacksmiths decided to get 
together with the Earth faction to mine the Abundance land that were empty for more than 100 years. They were having children at this time, that needed the land and crystals to develop their activities. They were asking for a new land law, when Drog, 
from the Earth faction, decided to put on vote the new land reform law. The blacksmiths, leaded by Klara, built their new Fire faction and joined the miners, from the new Earth faction.

The Cyber Faction was formed by Tempus, after the great war. When Necro, Tilt and the air gnomes returned to Abundance, they saw that the Earth faction and Fire faction had mined their land and controlled it. Fire and Earth gnomes became rich, and the Air, 
Water and Dark gnomes became poor. After 10 years, Tilt and the air gnomes decided to attack the fire and earth gnomes, and Necro blamed them all and decided to use his new dark machine to invoke the dead. The war took 1000 years, and Abundance turned into 
qScarcity after that. The only chance to get Scarcity back to the old days, as Tempus believes, is going back in time and do something to forbid the gnomish split in the old days. Can Abundance/Scarcity be saved?

# %% [markdown]
# ## Cielxnoel

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488832004510658563"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488832004510658563"></a>
# </blockquote>

# %% [markdown]
# When the Astrocryptids needed to flee from the Observatory for their safety, they also needed a place to continue the experiments that combined organic matter and technology to create new life forms. The same technology had created the cryptids and needed to be continued. They established their new Observatory on Shinjuku island and the island of Scarcity was chosen as the place to further their experiments.
#
# Even though the land on Scarcity had undergone heavy mining, there was still plenty of resources and remnants of magic from the previous civilization to create a safe haven for the next experiment: the Astrokytties.
#
# Several sites were chosen and excavated for creating the Astrokyttie Factory, the Astrokyttie Bakery that would supply the cafes needed to fund the work, and the Astrokyttie Ice Cream shop. These sites were excavated and strange rare minerals and materials were found and contained for further study at a later date.
#
# The factory was built and the Scarcity mines were used to gather raw materials. Soon the Astrokyttie Factory was in full swing and the first astrokytties were being sent to the kyttie care and training. One curious astrokyttie wandered away from their exercises down into the basement where they discovered a strange small being hacking away at the wall with a pickaxe, trying to widen a passageway through the way.  The astrokyttie made friends with the being which was called a gnome and learned it had been hiding with its kin in the interdimensional tunnels that filled the underground on Scarcity. Building the factory had closed up the portal and they needed to get in and out to get supplies to survive. The supervisor of the factory was summoned and it was discovered that the site the building had been built on was territory belonging to the Dark gnome faction long ago. The gnomes had waned in power, after many years of war, and had been hiding to help protect the few that were left. A survey of the other two sites purchased for the project revealed a hidden water gnome faction and fire gnome faction, all weakened and hiding in the interdimensional portals. They were survivors of the older civilization driven underground after much fighting, barely able to sustain themselves.
#
# As these factions were old enemies and their territory was being developed by the Astrokytties, a power struggle threatened to break out. But the Astrocryptids negotiated that the three territories be a peaceful haven for any gnome from any faction as long as they promised to not fight within the boundaries. Any gnome could get food and was welcomed as company at the factory, bakery, or ice cream shop as gratitude for the use of the land. The Astrocryptids and Astrokytties agreed to share their own brand of magic and technology to help the gnomes survive and begin to rebuild their society in exchange for their expertise and help mining the resources left in Scarcity sustainably.

# %% [markdown]
# ## Clunys Clothes

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1478426664740687872"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1478426664740687872"></a>
# </blockquote>

# %% [markdown]
# ## Cluny the Scourge
# is an enormous rat. Missing one eye and grizzled from a life of piracy, much leaner than his warlord days after years of life as a hermit in the wilds of Mossflower - Cluny once again feels the familiar itch to travel the seas. But now Cluny voyages in search of meaning and redemption and may have found both on the shores of Scarcity Island. While soaking in the natural hot springs on top of a crystal tower, Cluny decided Scarcity was home.
#
#  The following are Cluny's reports to the Lost Gnome Society of discoveries made while exploring the island and the caverns below the Crystal Staircase.

# %% [markdown]
# https://peakd.com/cryptovoxels/@cluny.the.rat/clunys-scarcity-chronicles-foreward-and-chpt1
# *Also see Cluny's first person narrative blog - largely distilled from the material originally shared in the CryptoVoxels Discord and found here on this website*

# %% [markdown]
# ## The Crystal Staircase (29 Emerald Avenue)
# https://www.cryptovoxels.com/parcels/6619

# %% [markdown]
# - Carved out of the solid rock and crystal by the ancients in the before times.
# -  A staircase to the sunless sea below Scarcity and the caverns beyond.
# - Rooftop soaking pools have healing properties.
# - There are gnome zombies down below and a rare zombie dolmentaz crystal (dark faction NFT discovery) on the rooftop

# %% [markdown]
# As I continue to chip away at the matrix holding the Crystal Staircase I have made a few more discoveries.
#  -  First, the crystal is a hydrated solid containing water of crystallization trapped inside the crystal lattice.
#  - Second, analysis of the water and dissolved contaminants excluded from the crystal formation indicate to me the presence of a deep subterranean sea below my parcel.
#
#  I know there must be a fissure of considerable size below my basement because the magic dragonturtle must have crawled up from this dark sea.
# This also casts a new light on the lore my zombie gnome informants first told me about the crystal staircase - they said it was an ancient crystal carved into a staircase to the "open world". At the time, I thought this was a very prescient allusion to the metaverse / web3. I realize now it is a staircase up to the open world (our world, the world with a sky) from the hollow world, Jules Verne Journey to the Center of the Earth style.
#
# This crystal is growing out of huge caverns in the underdark, which I wager contain much more than the dark sea I mentioned before.
# On a related fun build note you can now swim from the rooftop soaking pools down into the flooded basement through a connected series of flooded chambers inside the Crystal Staircase.

# %% [markdown]
# This turtle dragon thing crawled out of the pool at the basement of my plot. I think it was drawn to the energy coming from the zombie stone. It is floating around above the zombie stone now basking in its radiation.  I checked in on the dragon turtle again this morning and it seems to have settled in. It is still lolling around basking in the radiation from the zombie stone and I swear it has grown larger since last night. I also noticed it is shimmering in time with the killer riffs emanating from @nic 's giant guitar & the pick of destiny. So far it seems harmless enough though. Maybe I will turn it into a wearable steed

# %% [markdown]
# so this is actually strange. My basement flooded at 29 Emerald (a temporary glitch - thanks @bitpixi.eth for screencap of flood!)
#
# I thought it looked cool and with bitpixi's help sort of recreated the effect of flooded basement - it fits my lore that the pool of water at the bottom of the basement was a portal, and the dragonturtle came up from there.
#
# I moved my avatar into the flooded basement and when I came back out I saw myself still sitting there on the road! Did I... did I just go into a mirror dimension when I entered the water and now I am stuck in this side while my doppelganger is roaming around in the real world?!?
#
# I'm having a stare off with my doppelganger. I can't figure out if I am stuck in the mirror dimension or my doppelganger is
#
# nic — 12/18/2021
# I saw this happen glad I kept a safe distance

# %% [markdown]
# ## Zombie Alien Parasites

# %% [markdown]
# Well things are just going from weird to worse 🙂 I was just strolling by the Bronze treasury and yeah damned if I didn't see a zombie neck stabber hanging out under the weird zombie dark crystal 😳  Cons of a zombie neck stabber infestation include that they will inject nanobots from the future into your neck - this will turn you into a zombie. There is an interesting pro however - until you turn into a zombie, you can see into the past through the neck stabber's eyes.

# %% [markdown]
# My gnome zombie informant was correct, there are definitely zombie heart displacers in the Bronze treasury 😳  They crawl around kinda like scorpions but as a wearable this would replace the torso with the row of green being the backbone and the "legs" turning into a skeletal rib cage with no heart. If you let one crawl onto you it will turn you into a zombie, but your heart will be displaced into a future timeline (possibly saving your mortal soul). To reiterate the bit of gnome lore I mentioned above, a popular gnomish heresy holds that the soul resides in the heart, while gnome orthodoxy of course holds that the soul resides in the tip of the pointy hat

# %% [markdown]
# I'm getting some interesting results from preliminary analysis of the neck stabbers & heart displacers using the cyberpunk artifacts I recently uncovered.  Both creatures appear to be genetically modified organisms created by splicing genes from a yet unidentified alien species with terrestrial arthropods. I was able to isolate some proprietary gene sequences created by Akaromi BioCorp, which is a little confusing considering Akaromi is known as an AgriCorp. The machinery I am using itself was manufactured by Arasaka MegaCorp, but had been rooted & jailbroken at some point in the past. I think there may be a gnome hacker resistance in the cyberpunk timeline that has been using the tools of the corporations against them.

# %% [markdown]
# Goblinhead Spiders have appeared on scarcity - they appear to be controlling the other alien creatures. Now available as a wearable - intended either as the bottom piece of a three piece set, with the Zombie Heart Displacer connecting to the tail of the goblinhead spider (with the goblinhead in the rear facing away from the neck stabber head on top of the heart displacer, with the whole thing kind of like a spider-taur) - or worn as a head piece on its own with the goblinhead in front.

# %% [markdown]
# ## Gnome Lore

# %% [markdown]
# The gnomes are a little prudish huh. They even wear their pointy hats and long stockings while swimming lol

# %% [markdown]
# I just learned something about gnomes while sculpting a gnome head. Please never confuse a gnome with a dwarf. Everyone knows dwarves are inferior because they only have one beard, while all proper gnomes have two beards.
#
# Also did you all hear the rumor that there is only one sex of gnomes and they reproduce by crafting crystal babies?
# My gnome informants have been very cagey on the topic. Can't get much out of them

# %% [markdown]
# #### The Heresy of Hagarthi the Immaterial
# An ascetic gnome monk retreated to a mountain cave for a decade of fasting in silence and was never seen again. A search party from the monastery was sent on the 11th year and found only Hagarthi's pointy hat sitting pristinely in the middle of the cave. The hat began emanating vibrations in the 11th dimension once placed in the Vault of Reliquaries back in the monastery, causing the same recurring dream for all the monks in the monastery.
#
#  In this dream Hagarthi appeared and shared a revelation: After achieving a transcendent state in meditation, Hagarthi's body de-materialized and regained consciousness after meditation as the hat. Hagarthi had glimpsed the true nature of Gnomish reality; the physical body is but a reflection of the true gnome which always resides in a pointy hat (the pointy shape serving as a conduit between the false reality and the true hativerse).
#
# This revelation was rejected as a heinous heresy of the 12th degree at the third council of Hrghrvtfffan and Hagarthi's hat was removed to the crypts. Hagarthi re-materialized from the hat (in the eyes of some observers proving the heresy correct) and promptly marched the hat back to the Vault of Reliquaries whence Hagarthi de-materialized again and the hat has remained ever since.
# Adherents to the Heresy of Hagarthi left behind a scroll which seems to imply that the pointy hats found around Scarcity are actually the missing gnomes in a state of suspended potentiality, perhaps waiting for the vibration of the perfect frequency to return.

# %% [markdown]
# Cluny.eth — 12/19/2021
# @jamesfinnerty.eth The beep boop beep bip robot tinkling noises? This is intriguing...  By Hagarthi's Beard you were right! I followed the noises to their source and located the hat!!!

# %%
import json
import urllib.request as request

# Village Voxel Shop

t = []
for i in range(0,20):
  url = f"https://www.cryptovoxels.com/c/638/{i}"; print (url)
  try:
    response = request.urlopen(url)
    data_json = json.loads(response.read()) 
    for attr in data_json['attributes']: data_json[ attr['trait_type'] ] = attr['value']
    del data_json['attributes']  
    t.append(data_json)
  except: pass
# Out:
# https://www.cryptovoxels.com/c/638/0
# https://www.cryptovoxels.com/c/638/1
# https://www.cryptovoxels.com/c/638/2
# https://www.cryptovoxels.com/c/638/3
# https://www.cryptovoxels.com/c/638/4
# https://www.cryptovoxels.com/c/638/5
# https://www.cryptovoxels.com/c/638/6
# https://www.cryptovoxels.com/c/638/7
# https://www.cryptovoxels.com/c/638/8
# https://www.cryptovoxels.com/c/638/9
# https://www.cryptovoxels.com/c/638/10
# https://www.cryptovoxels.com/c/638/11
# https://www.cryptovoxels.com/c/638/12
# https://www.cryptovoxels.com/c/638/13
# https://www.cryptovoxels.com/c/638/14
# https://www.cryptovoxels.com/c/638/15
# https://www.cryptovoxels.com/c/638/16
# https://www.cryptovoxels.com/c/638/17
# https://www.cryptovoxels.com/c/638/18
# https://www.cryptovoxels.com/c/638/19

# %% [markdown]
# ## Cyberpunk Artifacts

# %% [markdown]
# The machinery in the Scarcity Research Lab was manufactured by Arasaka MegaCorp, but has been rooted & jailbroken at some point in the past. I think there may be a gnome hacker resistance in the cyberpunk timeline that has been using the tools of the corporations against them.

# %% [markdown]
# I reversed the polarity of the circuit connected to the cyberpunk crystal and attempted to send a broadcast to any cyberpunk gnome hackers out there - I'm not sure if it was received, the crystal began overheating and I had to kill the broadcast. I will report back if I hear anything in return.

# %% [markdown]
# My plan with the cyberpunk artifacts is to make them modular so they can be assembled together into lots of different configurations. Also since they have been rooted/jailbroken, the cyberpunk gnome hackers have loaded lots of different functionalities into units that may look the same (just swap out some display GIFs and that could be a replicator, or a shower, or put an "occupied" sign and it is a portapotty etc. LOL. Then of course we may find some of the unmodified original equipment that the corporations were using, unclear what the original purpose was but it had something to do with the alien creatures and the zombie nanobot plague.  Also, these will be wearables that can be used to make a weird cyborg kind of costume once I have it all figured out 🙂 Happy new year all and cheers to lots more weirdness in scarcity!

# %% [markdown]
# Thanks to the awesome @BeeBee my cyberpunk artifact research lab is now protected with blast doors which can only be opened by pressing the big red button on the security pad  🙂  Having to use the red button actually fits with the cyberpunk gnome hacker lore, they obviously bypassed the corporation's biometric security with these big red buttons they added LOL.  Try the doors out and investigate the research lab (if you dare)

# %% [markdown]
# it looks like the gnome hackers were trying to reverse engineer one of the infamous Arasaka Scanner Slicers but I am not sure it is safe to approach!  (I will eventually be adding these cyberpunk artifacts to the library but for now they mostly live in the research lab space here

# %% [markdown]
# can't get the "add group to library" feature to work tonight or I would have added a cyberpunk artifact builder's kit. I did add the five cyberpunk artifacts I have discovered so far to the Bronze treasury. These modular units are intended to fit together in a variety of ways, think of them like Lego for tech artifact building 🙂 Let me know if you make anything out of these 🙂 I'm going to just add the vox files here for now until I can add the group to the asset library

# %% [markdown]
# just made a Goggles & Respirator wearable - the green crystal lenses let you see into the past/future/alternate dimensions (similar to how you can see through the eyes of a neck stabber, less the turning you into a zombie) and the respirator filters out spores & zombie plague nanobots. This will be handy as we explore deeper under Scarcity

# %% [markdown]
# lookin' good - just womped The Anvil, that was the best coffee I have had in the many metaverses! One wonders if the reason I now seem to be able to breathe underwater has anything to do with these special Scarcity grown beans 🤔

# %% [markdown]
# I have been a bit puzzled why the Scarcity Research Lab (https://www.cryptovoxels.com/s/scarcityresearch ) is on the moon, and why the same types of crystals found around Scarcity seem to also be common on the lunar surface. So on a hunch I analyzed some rocks I collected from the moon and compared them to the rock composition in and around Scarcity. It appears that the huge caverns underneath Scarcity are actually evidence of the ancient impact that separated the moon from the world! The crystals formed both on Scarcity and the moon as the rock slowly cooled after the impact. The crystals are still connected - it is easy to send energy between pairs of like crystals in Scarcity and on the moon!

# %% [markdown]
#  have been exploring the caverns under Scarcity. I have seen things in these sunless realms that defy explanation. What I learned in the caves withered and bleached my paltry human intellect but fear not I have emerged from the flames stronger for the forging.

# %% [markdown]
# https://www.cryptovoxels.com/spaces/bf68aea9-c0dc-4a91-a708-f141b62c7aa8/play

# %% [markdown]
# https://www.cryptovoxels.com/spaces/b715781f-27f1-418c-8b95-1c645f672dda/play

# %% [markdown]
# - Astrokyttie Factory site: 13 Analcime
# - Astrokyttie Bakery site: 5 Analcime
# - Astrokyttie Ice Cream shop: 7 Analcime

# %% [markdown]
# I can't remember where the mushrooms came from - @bitpixi.eth @karpatic I think it was the ethical hackers guild maybe and a bunch of mushrooms sprouted up? Anyway I followed the mycelial networks down through the cave systems I have been exploring and it turns out the mushrooms are related to a D&D adventure I cowrote/produced a while back (I'm Carl, it me).
#
# In the published text we didn't clarify what the source of the magical radiation was that was causing the crazy magic mushroom mutations. Remember I noted that the same magic faction crystals occurring around Scarcity also occur on the moon?  It turns out this has created a resonant energy field from the crystal caves under Scarcity all the way up to the moon. Many of the dimensional/time instabilities/fractured timelines we are seeing are likely a result of this field.  This is also causing the insane mushroom growth in the undercaverns, the mycelial networks are feeding off the magical energy and expressing properties of all the factions.
#  https://www.drivethrurpg.com/product/178717/The-Fungus-Forest

# %% [markdown]
# BTW this is a "pay what you want" PDF so if you want to check out the adventure, just put "$0" in the field and you can download it for free

# %% [markdown]
#  2 Cycas & 3 Cycas Terrace

# %% [markdown]
# 2 Cycas Terrace I want to keep the mother tree

# %% [markdown]
#  It is quite possible that one of the megacorps from the cyberpunk future/alternate present got a hold of some of the Astrocryptids' experimental life forms and mutated them to their own purposes - from what I have gathered so far, there were at least two megacorps involved in this, initially an agricorp was creating alien clone workers (possibly from a base creature created by the Astrocryptids I am thinking now?) to tend the mycelial farms underneath Scarcity, and then a separate military/tech corp modified the agricultural clone workers to create the zombie alien parasites. Lots to chew on

# %% [markdown]
# https://mobile.twitter.com/Cluny_the_Rat/status/1485525817727750146

# %% [markdown]
# ## James Finnerty

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488261639161974786"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488261639161974786"></a>
# </blockquote>

# %%
import json
import urllib.request as request

# Village Voxel Shop

t = []
for i in range(0,10):
  url = f"https://www.cryptovoxels.com/c/697/{i}"; print (url)
  try:
    response = request.urlopen(url)
    data_json = json.loads(response.read()) 
    for attr in data_json['attributes']: data_json[ attr['trait_type'] ] = attr['value']
    del data_json['attributes']  
    t.append(data_json)
  except: pass
# Out:
# https://www.cryptovoxels.com/c/697/0
# https://www.cryptovoxels.com/c/697/1
# https://www.cryptovoxels.com/c/697/2
# https://www.cryptovoxels.com/c/697/3
# https://www.cryptovoxels.com/c/697/4
# https://www.cryptovoxels.com/c/697/5
# https://www.cryptovoxels.com/c/697/6
# https://www.cryptovoxels.com/c/697/7
# https://www.cryptovoxels.com/c/697/8
# https://www.cryptovoxels.com/c/697/9

# %% [markdown]
# When the hunt for the lost gnomes begins, I figured it would be useful to have someplace to plan out missions, organize expeditions and such. I'm proposing we form the 'Lost Gnome Society' using Bronze Town Hall as its headquarters. All in favour?

# %% [markdown]
# I emerged from the underworld far below to discover some strange vibrations emanating from within the Bronze mines. I highly suggest you take a look.

# %% [markdown]
# jamesfinnerty.eth — 12/18/2021
# To my understanding, after Hagarthi rematerialized to human form and left the hat, a strong 11th dimension vibration artifact remained within the hat itself. These vibrations, if aligned with other gnome relics in its surroundings, could cause a sympathetic resonance, potentially resulting in the hat spawning multiple iterations of itself outside of the vault. Gnome relics were often kept buried underground to prevent such an occurrence, since it was known that the hat spawns could bring about unpredictable occurrences (ie, bad weather, upside down worlds, etc).
#
# Now, for anyone who has spent some time studying the origins of sound, it’s clear that an 11th dimension frequency takes on a “cloud like” or “granular” quality. If you listen carefully it appears that the sounds coming from ‘Ol Bronze just so happen to match that quality! This could mean that a recent hat spawning could — or might already have — taken place…
#
# Now, we don’t know the true location of the Vault of Reliquaries, and we can’t assume that it might actually be in or near the Bronze mines. However, with the amount of digging and building that has been taking place, it’s possible that some gnome relics were discovered, unburied and moved. Exposing these relics might have accidentally put them in direct alignment with the vault, amplifying the 11th dimension frequencies of the hat, and initiating a new wave of spawning.
#
# I would wander around in the maze a bit more before starting to dig. It could be that any further displacement would put these frequencies out of alignment, risking the potential of discovering any newly spawned hats.
#
# Keep searching… these things are usually in plain sight.

# %% [markdown]
# ## JackDee

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1487875187089494023"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1487875187089494023"></a>
# </blockquote>

# %%
import json
import urllib.request as request

# Jacks Stuff

t = []
for i in [7, 6, 2]:
  url = f"https://www.cryptovoxels.com/c/584/{i}"; print (url)
  try:
    response = request.urlopen(url)
    data_json = json.loads(response.read()) 
    for attr in data_json['attributes']: data_json[ attr['trait_type'] ] = attr['value']
    del data_json['attributes']  
    t.append(data_json)
  except: pass

# %% [markdown]
# @Cluny.eth said once I pass the Bee Helmet initiation I get to join some secret club, he didn't say how long I have to wear this though...

# %% [markdown]
# No spaceman but other spirits have arrived I just woke up so all I know is it took more than 8 hours. Am I the first ghost hunter on scarcity?

# %% [markdown]
# These spirits will not rest lol
# no one else can see them but me I hope I am not some kind of gateway for this activity

# %% [markdown]
# The discoverable on my parcel may have manifested itself an electric guitar to let me know that it is in fact the "Pick of Scarcity"

# %% [markdown]
# legend has it that depending on the chord played the worlds graphics change to a different generation of Playstation ad infinitum

# %% [markdown]
# ## 4everKurious

# %% [markdown]
# https://www.cryptovoxels.com/parcels/6611

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488832754250829824"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/x/status/1488832754250829824"></a>
# </blockquote>

# %% [markdown]
# 3 Collinsite Ave | Cryptovoxels

# %% [markdown]
# 3 Athabascaite Street | Cryptovoxels

# %% [markdown]
# 3 Sapphire Terrace | Cryptovoxels

# %% [markdown]
# So all of the pottery at my home goods tore is made from the clay and minerals that is dug up from the Scarcity digs . just a tiny fact!!

# %% [markdown]
# Scarcity office mining

# %%
import json
import urllib.request as request

# 4everKurious Studio

t = []
for i in range(0,70):
  url = f"https://www.cryptovoxels.com/c/804/{i}"; print (url)
  try:
    response = request.urlopen(url)
    data_json = json.loads(response.read()) 
    for attr in data_json['attributes']: data_json[ attr['trait_type'] ] = attr['value']
    del data_json['attributes']  
    t.append(data_json)
  except: pass

# %% [markdown]
# ## CARD

# %%
<ion-card>
  <ion-card-header>
    <ion-card-subtitle>Card Subtitle</ion-card-subtitle>
    <ion-card-title>Card Title</ion-card-title>
  </ion-card-header>

  <ion-card-content>
    Keep close to Nature's heart... and break clear away, once in awhile,
    and climb a mountain or spend a week in the woods. Wash your spirit clean.
  </ion-card-content>
</ion-card>

<ion-card>
  <ion-item>
    <ion-icon name="pin" slot="start"></ion-icon>
    <ion-label>ion-item in a card, icon left, button right</ion-label>
    <ion-button fill="outline" slot="end">View</ion-button>
  </ion-item>

  <ion-card-content>
    This is content, without any paragraph or header tags,
    within an ion-card-content element.
  </ion-card-content>
</ion-card>

<ion-card>
  <ion-item href="#" class="ion-activated">
    <ion-icon name="wifi" slot="start"></ion-icon>
    <ion-label>Card Link Item 1 activated</ion-label>
  </ion-item>

  <ion-item href="#">
    <ion-icon name="wine" slot="start"></ion-icon>
    <ion-label>Card Link Item 2</ion-label>
  </ion-item>

  <ion-item class="ion-activated">
    <ion-icon name="warning" slot="start"></ion-icon>
    <ion-label>Card Button Item 1 activated</ion-label>
  </ion-item>

  <ion-item>
    <ion-icon name="walk" slot="start"></ion-icon>
    <ion-label>Card Button Item 2</ion-label>
  </ion-item>
</ion-card>

# %% [markdown]
# https://app.ens.domains/name/cvminigames.com
#
# Fishbrain
#
# Burning 1 talisman redeems for a REAL cassette tape of the track, and a VOXEL cassette tape collectible.
#
# Combining and burning all 8 talismans redeems for the PHYSICAL VINYL, and a VOXEL VINYL collectible.
#
# So my question, is there a way we can send you a portion of the supply to distribute through future islands?
#
# We already have a deal with Cometh to distribute some of them this way, so just looking for as many outlets as possible.

# %% [markdown]
# Just wait until you see my Rare Coprolith of a Roginspar Aqrabuamelu Face with tears of joy (the fossilized poop of a half-scorpion half-man who can animate statues and render zombie parasites harmless with a cold fire.. who was once a statue himself by gnome artist Thistle Rogin) Gnome recursion...
