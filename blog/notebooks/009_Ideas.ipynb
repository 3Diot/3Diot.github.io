# %% [markdown]
# # Ideas
# > Here is a list of community provided ideas!
#
# - toc: true
# - filename: Ideas
# - tab: CVMinigames | Ideas
# - title: CVMinigames
# - template: article
# - description: this isnt working
# - image: images/company_logo.png
# - words: thisworks
# - badges: true
# - comments: true
# - categories: [test]
# - hide: false
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2

# %% [markdown]
# Below are a list of user-suggestions

# %% [markdown]
# <details>
# <summary>

# %% [markdown]
# Here are a list of community suggestions provided for logging, tracking progress, advancing conversations, and inspiring new ideas. What's listed here is not guaranteed to come so be sure to check out our official [RoadMap](https://trello.com/b/0eMw7Y5p/cryptovoxels-roadmap-2022).

# %% [markdown]
# ## OnBoarding

# %% [markdown]
# </summary>

# %% [markdown]
# <style>
#     details{ background: #eee; display: inline}
#     summary{ color: gray; background: #fff }
# </style>
#
# <li> Introductory/ onboarding 'welcome' page & flow <details ><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Better wearables Support & editor UI <details ><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Scripts: syntax highlighting & error reporting <details ><summary style='color:green'>(More+)</summary>We did it!</details> </li>
#
# <li> &noob=true <details ><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Annon: dress, names, talking (w /mute btn) <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> voxels.com/ ens name <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li>auto-generated building started showing off their possessions <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li>Gnosis wallets <details><summary style='color:green'>(More+)</summary>Support Added!</details> </li>

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# ## Interactivity

# %% [markdown]
# </summary>

# %% [markdown]
# <style>
#     details{ background: #eee; display: inline}
#     summary{ color: gray; background: #fff }
# </style>
#
# <li> Defining character behaviors and interactions and other capabilities similar to The Sandbox. <details ><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Ability for items/players within your parcel to be damaged. <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Ability to attack items/players <detailsary>No information available at this time<detailsarys> </li>
#
# <li> Friendslist & chat features <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> RTMP server support <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> vidscreen support for binding any key <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> NFT ticketing (restrict access) (done) <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Import/Export builds to Spaces (done) <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> OBS direct stream support (HLS Direct stream support, not necessarily OBS) <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> In-world Opensea payments <details><summary>(NA)</summary>No information available at this time</details> </li>

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# </summary>

# %% [markdown]
# ## Social

# %% [markdown]
# <style>
#     details{ background: #eee; display: inline}
#     summary{ color: gray; background: #fff }
# </style>
#
# <li> Featured content <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> regular content: podcast, music, gaming, building livestreams <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Advanced (agenda) Invite links <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Community management of wireframe parcels <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Community DAOs. <details><summary style="color: orange">(More+)</summary>Someone suggested creating quadratic strategies on snapshot that recognizes the suburb variable in cv erc721 metadata
# https://github.com/snapshot-labs/snapshot-strategies#checklist-for-adding-a-new-strategy
# use existing quadratic strategies for reference, here
# https://github.com/snapshot-labs/snapshot-strategies/tree/master/src/strategies
# each suburb will need an ENS name to register their snapshot page
# & that's it. gasless voting per suburb using existing NFTs</details> </li>
#
# <li> Afer 2 months community editable wireframe plots. <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Districts Official Hubs <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> metaverse Live DJ / Musician service register <details><summary>(More+)</summary>Asking price per minute, availability and lead notice time.</details> </li>
#
# <li> daisy chains portals from OC spawn point. "official CV tour" <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Have global themes and events. <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Share assets to Public library (done) <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Mobile voice chat support <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Zoom/videoconferencing <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Audius integration <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Clubhouse integration <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Mute trolls (text and voice) (Tricky but working on it) <details><summary>(NA)</summary>No information available at this time</details> </li>

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# # Economics

# %% [markdown]
# </summary>

# %% [markdown]
# <style>
#     details{ background: #eee; display: inline}
#     summary{ color: gray; background: #fff }
# </style>
#
# <li> Offical source of communication for announcements and updates <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> brand affiliations <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> community relations mgmt <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> clarity/ rules around upcoming island parcel sizes <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> More voting for things and stuff <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Mintable builds <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Reinvigorate sales through Whitelist for hyped islands or discount for holders <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Integrated rental smart contract <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Pfp token and/or CV coin <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> increase the Dutch auction floor price <details><summary>(NA)</summary> No information available at this time</details> </li> </li>
#
# <li> What if the owner of the space would need to have a land to unlock 5+ people <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Parcel basements (mirror sized) (exist but not commonly offered) <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Incentivize builders => "CV award winner 2022" NFT. <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> More assets for larger parcels (considering it) <details><summary>(NA)</summary>No information available at this time</details> </li>

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# ## Performance/ Ease of Use

# %% [markdown]
# </summary>

# %% [markdown]
# <style>
#     details{ background: #eee; display: inline}
#     summary{ color: gray; background: #fff }
# </style>
#
# <li> Server: Uptime & max concurrent users <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Multi-parcel management <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Asset 3D click and drag edit <details><summary style='color:green'>(More+)</summary>Gizmos now provided!</details> </li>
#
# <li> Asset Grouping <details ><summary style='color:green'>(More+)</summary>Possible</details> </li> </li>
#
# <li> Permissioned boomboxes <details style='color:black; background:#eee'><summary style='color:green'>(More+)</summary>Parcel owners can now specify if the boombox is for contributors only or everyone</details> </li>
#
# <li> Seamless adjacent parcel editing <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Increase tile texture resolution <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Debaking only when editing tiles <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Undo button <details><summary style='color:green'>(More+)</summary>It is now possible to rollback a build to a prior state</details> </li>
#
# <li> Access all past uploaded assets <details><summary style='color:green'>(More+)</summary>Access past assets by reviewing your parcel change log off the parcel main-page</details> </li>
#
# <li> Filter + Sort + Search Assets <details><summary style='color:orange'>(More+)</summary>Sorting & Filter by type have been implemented</details> </li>
#
# <li> Seamless lightmaps <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> VOX shaders (light, alpha, etc) <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Megavox collision lag fix <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Stronger audio spatial rolloff <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Lanterns: orientation and focus <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Place images 1px away from walls <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> More wearables for costumes <details><summary style='color:green'>(More+)</summary>Increased from 7 to 9 and we are looking at increasing to 12 so as to match the sandbox.</details> </li>
#
# <li> Fix Youtube/Twitch crashes <details><summary style='color:green'>(More+)</summary>Fixed. But we'll keep our eyes peeled.</details> </li>
#
# <li> NFT Packs <details><summary>(More+)</summary>See [polygonpacks](https://polygonpacks.com/#/home) or [thirdweb](https://portal.thirdweb.com/contracts/design/Multiwrap).</details> </li>

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# ## Misc

# %% [markdown]
# </summary>

# %% [markdown]
# <style>
#     details{ background: #eee; display: inline}
#     summary{ color: gray; background: #fff }
# </style>
#
# <li> More love to old islands <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Road signs <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Day/Night switch modes and/or sunlight cycle <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> GIFs encode as full res video <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Copy/Paste asset parameters <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Video optimisation (reencode) <details><summary>(NA)</summary>No information available at this time</details> </li>
#
# <li> Moving Assets : reliable preview <details><summary>(NA)</summary>No information available at this time</details> </li>
