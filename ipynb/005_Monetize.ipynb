# %% [markdown]
# # Monetizing
# > People make money in the metaverse:
#
# - badges: false
# - comments: false
# - filename: Monetizing
# - hide: false
# - image: images/company_logo.png
# - keywords: ['voxels', 'money', 'work', 'employment', 'metaverse', 'tips', 'navigation', 'building', 'wiki', 'Monetizing', 'users', 'user-made', 'creators', 'content']
# - tab: Monetizing
# - template: template_article
# - toc: false

# %% [markdown]
# <details style='background:#eee'>
# <summary>

# %% [markdown]
# ## Development

# %% [markdown]
# </summary>

# %% [markdown]
# ### Building

# %% [markdown]
# Many people who buy land may not have the time or talent to develop the nice builds they desire. That's where you come in! Get on the CV discord and to look for commissioned builds, or advertise yourself!

# %% [markdown]
# #### Pre-made Parcels

# %% [markdown]
# Did you know that it's possible to sell an entire build without needing to own a parcel?
#
# It's true!
#
# Simple create a building using a free-to-create off-world '[Spaces](https://www.cryptovoxels.com/account/spaces)' parcel, create a video to show it off, then just export it's JSON and list the video on opensea with the json as unlockable content! When purchased, owners can take the unlocked json file and load their in-world parcel parcel with it.

# %% [markdown]
# #### On Commission

# %% [markdown]
# Not all, but quite a few of the parcels you see shown on Metacat's [Website](https://www.metacat.world/) were build for clients. This is a serious industry with professional designers and [architects](https://voxelarchitects.com/) entering the metaverse to serve this exact need! Patrick Wood's [Architecture](https://patrickwood.myportfolio.com/) Page demonstrates this beautifully.

# %% [markdown]
# ###  Websites

# %% [markdown]
# - [Metacat](https://www.metacat.world) - Specializing in Data Analytics and Content Navigation, Metacat has made a name for themselves an integral component of the CV community by providing insights, hosting events, and beyond
#
# - [School of Data Science](https://predictcrypto.org/school-of-data-science) - Ricky Espalon, who works at [the graph](https://thegraph.com/) uses his parcel to teach others how to use big data and the graph!
#
# - [cvminigames](https://cvminigames.com/) - Is the website I host and where I market my skills and provide free services to others!

# %% [markdown]
# ### Stories

# %% [markdown]
# Add value to your assets by creating compelling stories that people will want to own!
#
# Examples:
#
# - [Ancient Encounters](https://twitter.com/CryptoXoB) - The first immersive experience Ran by XoB, it had 750 people visit in the first 3 days. Play the game and buy their assets (if you like em)!
#
# - [Scarcity Discoveries](https://medium.com/@kasey_2741) - The entire island of Scarcity had themed NFT's buried underneath them. CVilians took these NFT's and ran with it; creating their own lore and more
#
# - [Scarcity Tales](https://opensea.io/collection/the-philosopher-brand) - One such CVilian, [the Philosopher](https://twitter.com/___Philosopher_), build off of Scarcities Discoveries and has expanded the lore onto every other island. Buy one of his parcels or associated NFT's to own a piece of the story!

# %% [markdown]
# ### Games

# %% [markdown]
# This is the path I took. After listening to countless Bankless podcasts where they told me to get a job in crypto and advising the best way to get started is by engaging with the community. I finally took the leap! People saw what I could do from the website I made, in-world builds, or through my participation on discord. Subsequently, I've found no shortage of work!

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# ## Promoting

# %% [markdown]
# </summary>

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/bitpixi/status/1496218372316532736"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/bitpixi/status/1496218372316532736"></a>
# </blockquote>

# %% [markdown]
# Have a project of your own with a ravenous fan base?
#
# Why not give them a place to call their own in the metaverse?
#
# Many projects have a presense here in cryptovoxels, here are just a few examples:
#
# - [JuiceboxDao](https://twitter.com/juiceboxETH) - is a programmable treasury for community-owned Ethereum projects with a strong creator base in Cryptovoxels
#
# - [DaoRecords](https://linktr.ee/DAOrecords) - Is a Web3 Record Label Launchpad & DAO with a homebase in CV

# %% [markdown]
# </details>
# <details style='background:#eee'>
# <summary>

# %% [markdown]
# ## Art

# %% [markdown]
# </summary>

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/k1ic234/status/1485554182778077184"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/k1ic234/status/1485554182778077184"></a>
# </blockquote>

# %% [markdown]
# This could fall into several other sections but I gave it it's own...
#
# Take note that there are many opportunities to showcase your art weather you have a parcel or not. (example above).
#
# And while there are so many artists, here is my favorites:
#
# - [Amazing Devya](https://www.amazingdevya.com/) - NFT Art & Book collection of our 10 y/o daughter Devya with Autism & SLD. All your proceeds go towards her therapy & art
# - [Alotta Money](https://alottamoney.com/) - A longstanding community participant, beloved creator, and a CV fan favorite. R.I.P.

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# ## Music

# %% [markdown]
# </summary>

# %% [markdown]
# One of my favorite aspects of the Cryptoverse is it's ability to expose you to new music.
#
# Here are just some of the unique ways I've been introduced something new:
#
# - [Coconut Sundays](https://www.youtube.com/coconutsunday) - Is a real world band with a really awesome sound. They broadcast every... SUNDAY, at [Scarcity Stadium](https://www.cryptovoxels.com/parcels/6629). Nic, who owns the stadium, will frequently give really nice wearables to attendees (Great guy, Great people)! Check out this 20 minute [exposé](https://www.youtube.com/watch?v=dbogjAAfnwo) by "Voice of a Nation"
#
# - [Tip your DJ](https://twitter.com/TipYourDjDotEth) - Is one of *the best dj's* in **the world** - and graces us with their presence, (whenever they please?), at the famous, one and only, [Bitpixi's Bar](https://www.cryptovoxels.com/parcels/5150)!
#
# - [CTRLrecords](https://twitter.com/CTRLrecords) - CTRL are international music artists from the early days of planetary Blockchains. They not just sell NFT Audio but also collectible voxels that can be redeemed for music! Lookout for out Fishbrain, our mastermind, in the metaverse :D
#
# - [DAORecords](https://www.daorecords.org/) - Created by the Rare Vandal; Catch events, DJs and launch parties inside a number of virtual venues, and check out the Audio NFTs! Visitors will sometimes even get some swag to wear for meta-verse video-shoots! Don't miss out on the latest develepments! Click [here](https://vandigital.medium.com/the-rare-vandal-music-video-shoot-listening-party-f58f9448499e) to read the latest news
#
# - [B.20](https://www.cryptovoxels.com/parcels/1162) - This $2.7M estate is infused with original soundscape by 3LAU. Three WOWs.. (WOW WOW)

# %% [markdown]
# </details>
# <details style='background:#eee'>
# <summary>

# %% [markdown]
# ## Events

# %% [markdown]
# </summary>

# %% [markdown]
# Money abound! Get paid to host, to perform or create!
#
# Possibilities include (but not limited to):
#
# Galleries, Movies, Clubs, Open-Mic Nights, Speed-dating, [Comedy Clubs](https://twitter.com/TheComedyVerse), AA Meetings

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# ## Premium Content

# %% [markdown]
# </summary>

# %% [markdown]
# Got something fire and you know it?
#
# Put that sucker behind a paywall and let the people come (at a price)!
# - [GrantingWishes](grantingwishesstudios.xyz) Studios - allows people to rent out their cinema for private and public showings, and much [more](https://www.grantingwishesstudios.xyz/)! With custom (nft) tickets gating access, users can keep a momento of the experience to boot!
# - [Ancient Encounters](https://cryptoxob.space) - Listed above, this story telling had a final room that requried purchase of cheap (~$5) matic items in order to reach and conclude it's story.
# - EulerBeats Genesis & Enigma - is an ultra scarce digital art + beat NFT collection generated on-chain. Their project caught the attention of [Marc Cuban](https://twitter.com/BanklessHQ/status/1364255520857731072) and their (token-gated) [parcel](https://www.cryptovoxels.com/parcels/5449) has even been featured in a JPMorgan report ![FLsnJXJXoAAhURU](https://pbs.twimg.com/media/FLsnJXJXoAAhURU?format=jpg)

# %% [markdown]
# </details>
# <details style='background:#eee'>
# <summary>

# %% [markdown]
# ## Renting/ Loans

# %% [markdown]
# </summary>

# %% [markdown]
# If you have a parcel put it to use!
#
# - Put a 'For Rent' sign with a way to reach you in your parcel and wait for fish to bite!
#
# - [NFTFI](https://www.nftfi.com/) - acts like a decentralized pawn shop that will let  you give or take out loans in exchange for CV Parcels
#
# - [MAD DAO](https://twitter.com/madxyz_) - in their own words "Creat[es] real business value in Metaverse, maximizing benefits of all community's properties and sharing profits with its members"
#
# - Stake with Land Development [DAO](https://www.landdevelopmentdao.com/)
#
# - [AdsharesNet](https://twitter.com/adsharesNet) - pays you for advertisement space!

# %%
# %%html
#
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/landworksxyz/status/1527171975076282368"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/landworksxyz/status/1527171975076282368"></a>
# </blockquote>

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# ## Competitions

# %% [markdown]
# </summary>

# %% [markdown]
# These can come in all shapes and sizes.
#
# Some can provide large monetary value like the 2021 Holiday Build Contest and at others, everybody's a winner!

# %% [markdown]
# </details>
# <details style='background:#eee'>
# <summary>

# %% [markdown]
# ## Guestbooks

# %% [markdown]
# </summary>

# %% [markdown]
# This isn't a really good way to make money. But signing guestbooks can yield access to all sorts of wonderful surprises!

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# ## Grants

# %% [markdown]
# </summary>

# %% [markdown]
# Do you have a big idea? Every so and often you can find organizations willing to fund it!
#
# Apply for grants from organizations big and small. Some examples include,
# - the [NEAR](https://gov.near.org/t/approved-metaverse-dao-funding-for-february-2022/14551) protocol - my friend actually applied for this (and was approved)!
# - [NEON](https://neondao.xyz/) DAO - A serious org looking to support serious-ly awesome projects

# %% [markdown]
# </details>
# <details style='background:#eee'>
# <summary>

# %% [markdown]
# ## Misc

# %% [markdown]
# </summary>

# %% [markdown]
# Networking, Consulting, Working for a Crypto Team ( Code, Design, Develop ). There are countless other ways to make money in the metaverse not listed.
#
# Here are some ways that may not have fit to well in other categories:
#
# - [cvParcels](https://twitter.com/cvparcels) - A twitter bot-account that posts Cryptovoxel Sales. Running the CVParcels would be a fine addition to anybodys resume
#
# - [NonFungibleBTC](https://www.youtube.com/channel/UC1jBiLeI9NenMevbc0TIpgw) - Jumping into the fray, NonFungibleBTC has been making Metaverse/ Crypto related videos and has been making a splash!
#
# - [Metaverse Cribs](https://www.youtube.com/watch?v=eDs5JXIfxxA) - Markets his video-production skills by making videos of CV Builders! -> Attached is a video he made of my 2021 Holiday Build Contest Entry!

# %% [markdown]
# </details>
# <details>
# <summary>

# %% [markdown]
# ## Speculating

# %% [markdown]
# </summary>

# %%
# %%html
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/cryptovoxels/status/1495626562942771202"></a>
# </blockquote>
# Out:
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# <blockquote class="twitter-tweet" style="display=inline">
#   <a href="https://twitter.com/cryptovoxels/status/1495626562942771202"></a>
# </blockquote>

# %% [markdown]
# There are more ways than one to speculate on the metaverse.
#
# The most common speculative activity is to buy a parcel for the long-haul and also USING IT (as intendid).
#
# Here are some other ways people have tried:
#
# - The Bronx [Zoo](https://zootoken.club/) - Was an interesting project where a zoo-token was created with the intention to fractionalize a parcel. More information in the link
#
# - [METAArchs](https://opensea.io/METAArchs ) - The foremost land speculators. You can often find them buying on discount and selling parcels for a profit

# %% [markdown]
# </details>
